# %%
import sys
import os
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, PROJECT_ROOT)
print(PROJECT_ROOT)
# Out:
# /Users/Nishnith.B/Library/CloudStorage/OneDrive-EQUITANEDMCC/Documents/Codes

# %%
import pandas as pd
from aws_db_conn import get_athena_client
from aws_db_exec import run_query, fetch_df
from aws_db_creds import DATABASE, S3_STAGING_DIR

# %%
import os

def load_sql(path):
    with open(path) as f:
        return f.read()

# Fix for Netskope/SSL error
os.environ['AWS_CA_BUNDLE'] = '/etc/ssl/cert.pem'

client = get_athena_client() 
query = load_sql("connections_vs_packets.sql")
print("Executing query...")
qid = run_query(client, query, DATABASE, S3_STAGING_DIR)
df = fetch_df(client, qid)
# Out:
# Executing query...
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/Library/CloudStorage/OneDrive-EQUITANEDMCC/Documents/Codes/Battery connectivity/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/Library/CloudStorage/OneDrive-EQUITANEDMCC/Documents/Codes/Battery connectivity/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# ...

# %%
df.head()
